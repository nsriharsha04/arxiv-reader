# %%
# Imports required for project
import arxiv
import datetime as dt
import urllib.request as libreq
import csv
import pandas as pd

# %% [markdown]
# Notes : dataframe.head() - Prints the first 5 records of the dataframe if available by default.

# %%
#  Artificial Intelligence - cs.AI , Machine Learning- cs.LG , Computational complexity- cs.CC , Harware Architecture - cs.AR

# To read data from csv and add to dataframe
df = pd.read_csv('papers_data.csv', encoding='utf-8')
print(df.head())

print('----------------------------***Artificial Intelligence***------------------------------')
# Segregate the dataframe into 'df_ai' based on 'cs.AI' primary category
df_ai = df[df['primary_category'] == 'cs.AI']
print(df_ai.head())

print('----------------------------***Machine Learning***------------------------------')
# Segregate the dataframe into 'df_lg' based on 'cs.LG' primary category
df_lg = df[df['primary_category'] == 'cs.LG']
print(df_lg.head())

print('----------------------------***Computational complexity***------------------------------')
# Segregate the dataframe into 'df_cc' based on 'cs.CC' primary category
df_cc = df[df['primary_category'] == 'cs.CC']
print(df_cc.head())

print('----------------------------***Harware Architecture***------------------------------')
# Segregate the dataframe into 'df_ar' based on 'cs.AR' primary category
df_ar = df[df['primary_category'] == 'cs.AR']
print(df_ar.head())
# Out:
#                                                title  \
# 0  Even $1 \times n$ Edge-Matching and Jigsaw Puz...
# 1  NIPS 2016 Tutorial: Generative Adversarial Net...
# 2  Classification of Smartphone Users Using Inter...
# 3  Closed Sets and Operators thereon: Representat...
# 4                     Outlier Robust Online Learning
#
#                                              authors  \
# 0  ['Jeffrey Bosboom', 'Erik D. Demaine', 'Martin...
# 1                                 ['Ian Goodfellow']
# 2  ['Andrey Finkelstein', 'Ron Biton', 'Rami Puzi...
# 3                     ['Carsten Rösnick-Neugebauer']
# 4          ['Jiashi Feng', 'Huan Xu', 'Shie Mannor']
#
#                                              summary  \
# 0  We prove the computational intractability of r...
# 1  This report summarizes the tutorial presented ...
# 2  Today, smartphone devices are owned by a large...
# 3  The TTE approach to Computable Analysis is the...
# ...
